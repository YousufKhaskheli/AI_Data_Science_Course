# %%
import pandas as pd

# %%
data = pd.read_excel("SaleData.xlsx")

# %%
data
# Out:
#     S.No.  OrderDate   Region  Manager   SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann     Shelli   Video Games   42.0
# 1       2 2019-08-24     West  Timothy    Stephen          Desk    3.0
# 2       3 2019-09-10  Central  Timothy      David    Television    7.0
# 3       4 2018-01-06     East   Martha  Alexander    Television   95.0
# 4       5 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann       Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN      David    Cell Phone   27.0
# 7       8 2018-03-15     West  Timothy    Stephen    Television    NaN
# 8       9 2018-04-01     East   Martha  Alexander  Home Theater   60.0
# 9      10 2018-04-18      NaN   Martha     Steven    Television   75.0
# 10     11 2018-05-05  Central  Hermann        NaN    Television   90.0
# 11     12 2018-05-22     West  Douglas    Michael    Television   32.0
# ...

# %%
# check how many different regions we have in data
data.Region.unique()
# Out:
# array(['Central', 'West', 'East', nan], dtype=object)

# %%
data.Manager.unique()
# Out:
# array(['Hermann', 'Timothy', 'Martha', nan, 'Douglas'], dtype=object)

# %%
data.Item.unique()
# Out:
# array(['Video Games', 'Desk', 'Television', 'Home Theater', 'Cell Phone',
#        nan], dtype=object)

# %%
data.SalesMan.unique()
# Out:
# array(['Shelli', 'Stephen', 'David', 'Alexander', 'Luis', 'Steven', nan,
#        'Michael', 'Sigal', 'Diana', 'Karen', 'John'], dtype=object)

# %%
data[data.Region=='Central']
# Out:
#     S.No.  OrderDate   Region  Manager SalesMan          Item  Units  \
# 0       1 2019-08-07  Central  Hermann   Shelli   Video Games   42.0
# 2       3 2019-09-10  Central  Timothy    David    Television    7.0
# 4       5 2018-01-23  Central  Hermann   Shelli  Home Theater   50.0
# 5       6 2018-02-09  Central  Hermann     Luis    Television   36.0
# 6       7 2018-02-26  Central      NaN    David    Cell Phone   27.0
# 10     11 2018-05-05  Central  Hermann      NaN    Television   90.0
# 13     14 2018-06-25  Central  Hermann    Sigal    Television   90.0
# 17     18 2018-09-01  Central  Douglas     John          Desk    2.0
# 19     20 2018-10-05  Central  Hermann    Sigal  Home Theater   28.0
# 22     23 2018-11-25  Central  Hermann   Shelli   Video Games   96.0
# 23     24 2018-12-12  Central  Douglas     John    Television   67.0
# 25     26 2019-01-15  Central  Timothy    David  Home Theater   46.0
# 26     27 2019-02-01  Central  Douglas     John  Home Theater   87.0
# ...

# %%
# total sales from west
data[data.Region=='West']['Sale_amt'].sum()
# Out:
# np.float64(88186.0)

# %%
# total Television sales in East
data[(data.Region=='East') & (data.Item=='Television')]
# Out:
#    S.No.  OrderDate Region Manager   SalesMan        Item  Units  Unit_price  \
# 3      4 2018-01-06   East  Martha  Alexander  Television   95.0      1198.0
#
#    Sale_amt
# 3  113810.0

# %%
# number of cellphones sold by Alexander in Central
data[(data.Region=='Central') & (data.SalesMan=='Alexander') & (data.Item=='Cell Phone')]
# Out:
# Empty DataFrame
# Columns: [S.No., OrderDate, Region, Manager, SalesMan, Item, Units, Unit_price, Sale_amt]
# Index: []

# %%
# number of cellphones sold by David in Central
data[(data.Region=='Central') & (data.SalesMan=='David') & (data.Item=='Cell Phone')]
# Out:
#    S.No.  OrderDate   Region Manager SalesMan        Item  Units  Unit_price  \
# 6      7 2018-02-26  Central     NaN    David  Cell Phone   27.0       225.0
#
#    Sale_amt
# 6    6075.0

# %%
# John and Diana total sales of videogames in central region
data[((data.SalesMan=='John') | (data.SalesMan=='Diana')) & (data.Item=='Video Games') & (data.Region=='Central')]['Sale_amt'].sum()
# Out:
# np.float64(0.0)

# %%
# every region total sale
data[data.Region=='Central']['Sale_amt'].sum()
# Out:
# np.float64(860681.5)

# %%
data[data.Region=='East']['Sale_amt'].sum()
# Out:
# np.float64(320080.0)

# %%
data[data.Region=='West']['Sale_amt'].sum()
# Out:
# np.float64(88186.0)

# %%
df = pd.read_excel('gby.xlsx')

# %%
df
# Out:
#    ids     Name  Age Designation  Grade  Dept  Salary
# 0    1    Nasir   23     Officer      15  Acc   123000
# 1    2      Ali   34       Clerk      16  Fin   200000
# 2    3   Faisal   23     Officer      17   IT   200000
# 3    4    Imran   45       Clerk      18   IT   230000
# 4    5   Kashif   54     Manager      18  Acc   231000
# 5    6    Saima   43     Manager      18  Fin   300000
# 6    7    Aqsa    32  Supervisor      17   IT   234000
# 7    8    Zoya    23     Manager      17   IT   250000
# 8    9    Salma   22     Manager      17  Fin   231000
# 9   10   Faheem   56     Officer      16   IT   100000

# %%
df.groupby('Designation')['Salary '].sum()
# Out:
# Designation
# Clerk          430000
# Manager       1012000
# Officer        423000
# Supervisor     234000
# Name: Salary , dtype: int64

# %%
df.columns=['ids','Name','Age','Designation','Grade','Dept','Salary']

# %%
df.groupby('Designation')['Salary'].sum()
# Out:
# Designation
# Clerk          430000
# Manager       1012000
# Officer        423000
# Supervisor     234000
# Name: Salary, dtype: int64

# %%
# Worst performing salesman on basis of total amount
data.groupby('SalesMan')['Sale_amt'].sum().sort_values()[:3]
# data.groupby('SalesMan')['Sale_amt'].sum().sort_values().head(3)
# Out:
# SalesMan
# Stephen    21350.0
# Shelli     33698.0
# Karen      48204.0
# Name: Sale_amt, dtype: float64

# %%
data.groupby('SalesMan')['Sale_amt'].aggregate(['sum', 'count', 'mean']).sort_values(by='count')
# Out:
#                 sum  count          mean
# SalesMan
# Michael     66836.0      2  33418.000000
# Karen       48204.0      3  16068.000000
# Sigal      125037.5      3  41679.166667
# John       167516.0      4  41879.000000
# Shelli      33698.0      4   8424.500000
# Diana       79300.0      4  19825.000000
# Stephen     21350.0      5   4270.000000
# Luis       101478.0      5  20295.600000
# Steven     199690.0      5  39938.000000
# David      212835.0      7  30405.000000
# Alexander  233076.0      8  29134.500000

# %%
data.groupby(['Region','SalesMan'])['Units'].agg('mean').to_excel('test.xlsx')

# %%
data.groupby(['Region','SalesMan'])['Units'].agg('mean')
# Out:
# Region   SalesMan
# Central  David        39.000000
#          John         60.750000
#          Luis         48.200000
#          Shelli       48.250000
#          Sigal        57.666667
#          Steven       36.000000
# East     Alexander    47.714286
#          Diana        79.250000
#          Karen        44.500000
# West     Michael      44.500000
#          Stephen      22.250000
# Name: Units, dtype: float64

# %%
data.groupby(['Region','SalesMan'])['Units'].agg('mean')
# Out:
# Region   SalesMan
# Central  David        39.000000
#          John         60.750000
#          Luis         48.200000
#          Shelli       48.250000
#          Sigal        57.666667
#          Steven       36.000000
# East     Alexander    47.714286
#          Diana        79.250000
#          Karen        44.500000
# West     Michael      44.500000
#          Stephen      22.250000
# Name: Units, dtype: float64
