# %%
alien_color = input("Enter  alien color: ").lower()
if alien_color == "green":
    print("You just earned 5 points")
# Out:
# Enter the alien color: green
# You just earned 5 points

# %%
alien_color = input("Enter  alien color: ").lower()
if alien_color=="green":
    print("You just earned 5 points")
else:
    print("You just earned 10 points")
# Out:
# Enter the alien color: Dark Gray
# You just earned 10 points

# %%
alien_color = input("Enter  alien color: ").lower()
if alien_color == "green":
    print("You just earned 5 points")
elif alien_color == "yellow":
    print("You just earned 10 points")
elif alien_color == "red":
    print("You just earned 15 points")
else:
  print("Wrong color!")
# Out:
# Enter the alien color: Maroon
# Wrong color!

# %%
person = input("Enter person name: ")
age = int(input("Enter age: "))
if age < 2:
  print(f"{person} is a baby")
elif age < 4:
  print(f"{person} is a toddler")
elif age < 13:
  print(f"{person} is a kid")
elif age < 20:
  print(f"{person} is a teenager")
elif age < 65:
  print(f"{person} is an adult")
else:
  print(f"{person} is an elder")
# Out:
# Enter person name: Abid
# Enter age: 65
# Abid is an elder

# %%
person = input("Enter person name: ")
age = int(input("Enter age: "))
if age < 2:
  print(f"{person} is a baby")
elif age>=2 and age<4:
  print(f"{person} is a toddler")
elif age>=4 and age<13:
  print(f"{person} is a kid")
elif age>=13 and age<20:
  print(f"{person} is a teenager")
elif age>=20 and age<65:
  print(f"{person} is an adult")
else:
  print(f"{person} is an elder")
# Out:
# Enter age: 34
# Abid is an adult

# %%
usernames = ['Israr','yousuf','admin','momin','ali','diablo']
for user in usernames:
  if user == 'admin':
    print(f"Hello {user}, would you like to see a status report?")
  else:
    print(f"Hello {user}, thank you for logging in again.")
# Out:
# Hello irar-khan, thank you for logging in again.
# Hello yousuf, thank you for logging in again.
# Hello admin, would you like to see a status report?
# Hello momin, thank you for logging in again.
# Hello ali, thank you for logging in again.
# Hello diablo, thank you for logging in again.

# %%
username = input("Enter username: ")
if username == 'admin':
  print(f"Hello {username}, would you like to see a status report?")
else:
  print(f"Hello {username}, thank you for logging in again.")
# Out:
# Enter username: adimin
# Hello adimin, thank you for logging in again.

# %%
# add an if test to hello_admin.py to make sure te list of users is not empty
usernames = []
# if len(usernames)!=0:
if usernames:
  for user in usernames:
    if user == 'admin':
      print(f"Hello {user}, would you like to see a status report?")
    else:
      print(f"Hello {user}, thank you for logging in again.")
else:
  print("We need to find some users!")
# Out:
# We need to find some users!
