# %% [markdown]
# # Nested Conditions

# %% [markdown]
# brand
# color
# size
# price

# %%
brand = input("Bonanza ki shirts hen? ")
color = input("Blue color hy?")
size = input("Large size hy?")
price = int(input("price kia hen?"))

if brand =='yes':
    if color == 'yes':
        if size=='yes':
            if price<2000:
                print("Good Please pack!")
            else:
                print("Price too high")
        else:
            print("No prblem")
    else:
        print("No problem")
else:
    print("No problem")
# Out:
# Bonanza ki shirts hen? no
# Blue color hy?no
# Large size hy?no
# price kia hen?5000
# Ok no problem

# %%
brand = input("Bonanza ki shirts hen? ")
if brand=='yes':
    color = input("Blue color hy?")
    if color == "yes":
        size = input("Large size hy?")
        if size =="yes":
            price = int(input("price kia hen?"))
            if price<2000:
                print("Ok pack karden!")
            else:
                print("price are high.")
        else:
            print("Ok no problem")
    else:
        print("Ok no problem")
else:
    print("Ok no problem")
# Out:
# Bonanza ki shirts hen? yes
# Blue color hy?yes
# Large size hy?yes
# price kia hen?1200
# Ok pack karden!

# %%
A = 23

# %%
A==23
# Out:
# True

# %%
math = int(input("Enter mathematics marks:> "))
if math >=50:
    english = int(input("Enter English marks:> "))
    if english >=50:
        urdu = int(input("Enter Urdu marks:> "))
        if urdu >=50:
            science = int(input("Enter Science marks:> "))
            if science >= 50:
                computer = int(input("Enter computer marks:> "))
                if computer >=50:
                    result = "Pass"
                else:
                    result ="Fail"
            else:
                result ="Fail"
                
        else:
            result ="Fail"
    else:
        result ="Fail"
        
else:
    result ="Fail"
    
print(result)
# Out:
# Enter mathematics marks:> 85
# Enter English marks:> 86
# Enter Urdu marks:> 82
# Enter Science marks:> 84
# Enter computer marks:> 85
# Pass
