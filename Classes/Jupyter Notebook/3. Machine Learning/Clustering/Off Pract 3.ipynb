# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pickle

# %%
diabetes_pred = pickle.load(open('binary_log_reg_model.sav','rb'))

# %%
diabetes_pred.predict([[6,148,72,35,0,33.6,0.627,50]])
# Out:
# array([1], dtype=int64)
