# %% [markdown]
# # FUNCTIONS
# - Functions are block of code that do some specific task
# - Whenever we need to do the task we call the function
# - It reduces the code
# - It makes code easier to debug the errors.

# %% [markdown]
# # Python Functions
# - print()
# - type() and etc..
# # Class Functions
# - list. functions
# - dictionary. functions
# - string  . functions
# # User Defined Functions
# - Functions we define to perform some specific task.

# %%
def say_salam():
  print("AssalamuAlaikum")

# %%
#function call / invoke function
say_salam()
# Out:
# AssalamuAlaikum

# %%
def add():
  a=10
  b=20
  res=a+b
  print(res)

# %%
add()
# Out:
# 30

# %% [markdown]
# ## Passing information to a function
# - argument value provided
# - parameter variable that stores provided values (arguments)

# %%
def say_salam(name):#parameter
  print(f"Mr.{name} AssalamuAlaikum")

# %%
say_salam()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5330/3078760585.py in <cell line: 0>()
# ----> 1 say_salam()
#
# TypeError: say_salam() missing 1 required positional argument: 'name'

# %%
say_salam('Yousuf')#argument
# Out:
# Mr.Yousuf AssalamuAlaikum

# %%
say_salam("Momin")#argument
# Out:
# Mr.Momin AssalamuAlaikum

# %%
def add(a,b):
  res = a+b
  print(res)

# %%
add(12,23)
# Out:
# 35

# %%
def sub(a,b):
  res = a-b
  print(res)

# %%
sub(45,15)
# Out:
# 30

# %%
def make_call(lst):
  for l in lst:
    print(f"Calling!... Mr.{l}, Hello")

# %%
make_call(['Asad','Nasir','Waqas','Kamran','Momin'])
# Out:
# Calling!... Mr.Asad, Hello
# Calling!... Mr.Nasir, Hello
# Calling!... Mr.Waqas, Hello
# Calling!... Mr.Kamran, Hello
# Calling!... Mr.Momin, Hello

# %%
#make a function that takes the list of numbers.
# function will print the squares of numbers greater than 10.
# function will print the cube of numbers less than 10.
def num_call(nums):
  for n in nums:
    if n > 10:
      print(f"The square of {n} is {n**2}")
    else:
      print(f"The cube of {n} is {n**3}")

# %%
num_call([12,3,45,65,23,9,8,7,56,3])
# Out:
# The square of 12 is 144
# The cube of 3 is 27
# The square of 45 is 2025
# The square of 65 is 4225
# The square of 23 is 529
# The cube of 9 is 729
# The cube of 8 is 512
# The cube of 7 is 343
# The square of 56 is 3136
# The cube of 3 is 27

# %%
a, b = 2, 4
print(a**2)
# Out:
# 4

# %%
print(b**3)
# Out:
# 64

# %%
def text_analyzer(txt):
  char_count = 0
  word_count = len(txt.split(" "))
  sentence_count = len(txt.split("."))-1
  upper_count = 0
  digit_count = 0
  space_count = 0
  vowels = 'aeiouAEIOU'
  vowel_count = 0
  punctuations = """!"#$%&'()*+,-./:;<=>?@[]/^_`{|}~"""
  punctuation_count = 0
  for char in txt:
    if char.isalpha():
      char_count+= 1
    if char.isupper():
      upper_count+=1
    if char.isdigit():
      digit_count+=1
    if char.isspace():
      space_count+=1
    if char in vowels:
      vowel_count+=1
    if char in punctuations:
      punctuation_count+=1
  print(f"""
        Word count           = {word_count}
        Character count      = {char_count}
        sentence count       = {sentence_count}
        capital letter count = {upper_count}
        number count         = {digit_count}
        space count          = {space_count}
        vowel count          = {vowel_count}
        punctuation count    = {punctuation_count}
        """)

# %%
text_analyzer("""Developing Paragraphs
If you think of a paragraph as a sandwich, the supporting sentences are the filling between the bread. They make up the body of the paragraph by explaining, proving, or enhancing the controlling idea in the topic sentence. The overall method of development for paragraphs depends upon the essay as a whole and the purpose of each paragraph; thus paragraphs may be developed by using examples, description, narration, comparison and contrast, definition, cause and effect, classification and division. A writer may use one method, or combine several methods.

Writers often want to know how many words a paragraph should contain, and the answer is that a paragraph should develop the idea, point, or impression completely enough to satisfy the writer and readers. Depending on their function, paragraphs can vary in length from one or two sentences, to over a page; however, in most college assignments, successfully developed paragraphs usually contain approximately one hundred to two hundred and fifty words and span one-fourth to two-thirds of a typed page. A series of short paragraphs in an academic essay can seem choppy and unfocused, whereas paragraphs that are one page or longer can tire readers. Giving readers a paragraph break on each page helps them maintain focus.

This advice does not mean, of course, that composing a paragraph of a particular number of words or sentences guarantees an effective paragraph. Writers must provide enough supporting sentences within paragraphs to develop the topic sentence and simultaneously carry forward the essay’s main idea.""")
# Out:
#         Word count           = 248
#         Character count      = 1313
#         sentence count       = 10
#         capital letter count = 12
#         number count         = 0
#         space count          = 252
#         vowel count          = 497
#         punctuation count    = 34

# %%
text_analyzer("I am a boy. I live in Karachi, in Gizri. I am 19 years old.")
# Out:
#         Word count           = 15
#         Character count      = 39
#         sentence count       = 3
#         capital letter count = 5
#         number count         = 2
#         space count          = 14
#         vowel count          = 19
#         punctuation count    = 4
