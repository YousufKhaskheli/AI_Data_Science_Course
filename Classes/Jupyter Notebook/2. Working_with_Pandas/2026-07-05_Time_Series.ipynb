# %% [markdown]
# #Date and Time Data Types and Tools

# %%
from datetime import datetime

# %%
today = datetime.now()

# %%
today
# Out:
# datetime.datetime(2026, 7, 11, 12, 12, 29, 318346)

# %%
today.date()
# Out:
# datetime.date(2026, 7, 11)

# %%
today.time()
# Out:
# datetime.time(12, 12, 29, 318346)

# %%
today.day
# Out:
# 11

# %%
today.month
# Out:
# 7

# %%
today.year
# Out:
# 2026

# %%
today.second
# Out:
# 29

# %%
today.hour
# Out:
# 12

# %%
today.year, today.month, today.day
# Out:
# (2026, 7, 11)

# %%
print(today.strftime('%A'))
# Out:
# Saturday

# %%
print(today.strftime('%a'))
# Out:
# Sat

# %%
delta = datetime(2011, 1, 7) - datetime(2008, 6, 24, 8, 15)

# %%
delta.days
# Out:
# 926

# %%
delta.seconds
# Out:
# 56700

# %%
from datetime import timedelta

# %%
start = datetime(2011, 1, 7)

# %%
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start - 2 * timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %% [markdown]
# ##Converting Between String and Datetime

# %%
dob = datetime(2000, 7, 5)

# %%
dob
# Out:
# datetime.datetime(2000, 7, 5, 0, 0)

# %%
dob.strftime('%d-%m-%Y')
# Out:
# '05-07-2000'

# %% [markdown]
# ### String to Date

# %%
value = '2011-01-03'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011']

# %%
[datetime.strptime(x, '%m/%d/%Y')for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %% [markdown]
# ##Time Series Basics

# %%
import numpy as np
import pandas as pd

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
        datetime(2011, 1, 7), datetime(2011, 1, 8),
        datetime(2011, 1, 10), datetime(2011, 1, 12)]

# %%
ts = pd.Series(np.random.randn(6), index=dates)

# %%
ts
# Out:
# 2011-01-02    0.410151
# 2011-01-05    0.880175
# 2011-01-07   -0.449390
# 2011-01-08    0.715807
# 2011-01-10   -1.585430
# 2011-01-12    1.777482
# dtype: float64

# %%
longer_ts = pd.Series(np.random.randn(100), index=pd.date_range('1/1/2000', periods=100))
longer_ts
# Out:
# 2000-01-01    0.618592
# 2000-01-02    1.471012
# 2000-01-03    0.531964
# 2000-01-04   -0.268718
# 2000-01-05    0.082978
#                 ...
# 2000-04-05   -0.431817
# 2000-04-06   -0.475825
# 2000-04-07    0.193279
# 2000-04-08   -0.677295
# 2000-04-09   -0.247569
# Freq: D, Length: 100, dtype: float64

# %%
longer_ts['2000-1-01':'2000-12-31']
# Out:
# 2000-01-01    0.618592
# 2000-01-02    1.471012
# 2000-01-03    0.531964
# 2000-01-04   -0.268718
# 2000-01-05    0.082978
#                 ...
# 2000-04-05   -0.431817
# 2000-04-06   -0.475825
# 2000-04-07    0.193279
# 2000-04-08   -0.677295
# 2000-04-09   -0.247569
# Freq: D, Length: 100, dtype: float64

# %% [markdown]
# #Date Ranges, Frequencies, and Shifting

# %%
longer_ts = pd.Series(np.random.randn(1000),
                      index=pd.date_range('1/1/2000', periods=1000, freq='h'))
longer_ts
# Out:
# 2000-01-01 00:00:00   -0.796909
# 2000-01-01 01:00:00   -0.548410
# 2000-01-01 02:00:00   -0.582272
# 2000-01-01 03:00:00   -0.739242
# 2000-01-01 04:00:00    0.016056
#                          ...
# 2000-02-11 11:00:00   -1.078375
# 2000-02-11 12:00:00   -1.910244
# 2000-02-11 13:00:00    1.949483
# 2000-02-11 14:00:00    0.766070
# 2000-02-11 15:00:00    0.386200
# Freq: h, Length: 1000, dtype: float64

# %%
longer_ts.head()
# Out:
# 2000-01-01 00:00:00   -0.796909
# 2000-01-01 01:00:00   -0.548410
# 2000-01-01 02:00:00   -0.582272
# 2000-01-01 03:00:00   -0.739242
# 2000-01-01 04:00:00    0.016056
# Freq: h, dtype: float64

# %%
longer_ts.tail()
# Out:
# 2000-02-11 11:00:00   -1.078375
# 2000-02-11 12:00:00   -1.910244
# 2000-02-11 13:00:00    1.949483
# 2000-02-11 14:00:00    0.766070
# 2000-02-11 15:00:00    0.386200
# Freq: h, dtype: float64

# %% [markdown]
# ###Resampling and Frequency Conversion

# %%
import matplotlib.pyplot as plt
longer_ts.plot()
plt.show()

# %%
plt.figure(figsize=(16,4))
plt.plot(longer_ts.resample('D').mean())
plt.show()
